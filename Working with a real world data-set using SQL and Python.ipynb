# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Working with a real world data-set using SQL and Python
#
# Estaimted time needed: **30** minutes
#
# ## Objectives
#
# After complting this lab you will be able to:
#
# *   Understand the dataset for Chicago Public School level performance
# *   Store the dataset in an Db2 database on IBM Cloud instance
# *   Retrieve metadata about tables and columns and query data from mixed case columns
# *   Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&download=true&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Store the dataset in a Table
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in the previous lab, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the CHICAGO PUBLIC SCHOOLS dataset and load the dataset into a new table called **SCHOOLS**.
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"><img src = "https://ibm.box.com/shared/static/uc4xjh1uxcc78ks1i18v668simioz4es.jpg"></a>

# %% [markdown]
# ### Connect to the database
#
# Let us now load the ipython-sql  extension and establish a connection with the database

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa
# Out:
# Requirement already satisfied: sqlalchemy==1.3.9 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.3.9)
# Requirement already satisfied: ibm_db_sa in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.3.3)
# Requirement already satisfied: sqlalchemy>=0.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ibm_db_sa) (1.3.9)

# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# %sql ibm_db_sa://trz01921:e5B9gpvzDoTSSQEX@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB?security=SSL
# Out:
# 'Connected: trz01921@BLUDB'

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('BDT30060', 'SCHOOLS', 'BDT30060', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 9, 4, 1, 34, 59, 881221), datetime.datetime(2021, 9, 4, 1, 34, 59, 881221), datetime.datetime(2021, 9, 4, 1, 34, 59, 881221), datetime.datetime(2021, 9, 4, 5, 12, 14, 75443), 78, 14, 890, 566, 15, 0, 16, -1, -1, -1, 0, 'BDT30060SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 9, 4, 1, 34, 59, 881221), 0, ' ', None, None, 'N', 'BDT30060', ' ', ' ', ' ', datetime.date(2021, 9, 4), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BFD18163', 'SCHOOLS', 'BFD18163', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 9, 17, 1, 18, 911347), datetime.datetime(2021, 8, 9, 17, 1, 18, 911347), datetime.datetime(2021, 8, 9, 17, 1, 18, 911347), None, 78, 4, 913, -1, -1, -1, -1, -1, -1, -1, -1, 'BFD18163SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, -1, 'N', 999, -1, -1.0, -1, -1.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', -1, datetime.datetime(2021, 8, 9, 17, 1, 18, 911347), 0, ' ', None, None, 'N', 'BFD18163', ' ', ' ', ' ', datetime.date(2021, 8, 9), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BFS81124', 'SCHOOLS', 'BFS81124', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 8, 20, 25, 57, 136253), datetime.datetime(2021, 8, 8, 20, 25, 57, 136253), datetime.datetime(2021, 8, 8, 20, 25, 57, 136253), datetime.datetime(2021, 8, 8, 20, 28, 5, 14664), 78, 13, 804, 566, 15, 0, 16, -1, -1, -1, 0, 'BFS81124SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 844, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 8, 20, 25, 57, 136253), 0, ' ', None, None, 'N', 'BFS81124', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BGF66040', 'SCHOOLS', 'BGF66040', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 9, 3, 16, 29, 2, 484228), datetime.datetime(2021, 9, 3, 16, 29, 2, 484228), datetime.datetime(2021, 9, 3, 16, 29, 2, 484228), datetime.datetime(2021, 9, 6, 23, 52, 15, 804119), 78, 7, 1563, 566, 15, 0, 16, -1, -1, -1, 0, 'BGF66040SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 9, 3, 16, 29, 2, 484228), 0, ' ', None, None, 'N', 'BGF66040', ' ', ' ', ' ', datetime.date(2021, 9, 6), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BHV82693', 'SCHOOLS', 'BHV82693', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 20, 5, 37, 48, 974234), datetime.datetime(2021, 8, 20, 5, 47, 57, 227516), datetime.datetime(2021, 8, 20, 5, 47, 57, 227525), datetime.datetime(2021, 8, 20, 5, 46, 55, 278988), 78, 12, 1567, 566, 15, 0, 16, -1, -1, -1, 0, 'BHV82693SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 20, 5, 37, 48, 974234), 0, ' ', None, None, 'N', 'BHV82693', ' ', ' ', ' ', datetime.date(2021, 8, 24), ' ', 'N', 'R', 'N', -1.0, None),
#  ('
PACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 7, 27, 11, 13, 50, 934409), 0, ' ', None, None, 'N', 'BTM14422', ' ', ' ', ' ', datetime.date(2021, 7, 27), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BTP87141', 'SCHOOLS', 'BTP87141', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 15, 19, 1, 23, 172061), datetime.datetime(2021, 8, 15, 19, 1, 23, 172061), datetime.datetime(2021, 8, 15, 19, 1, 23, 172061), datetime.datetime(2021, 8, 15, 19, 13, 4, 971744), 78, 4, 1504, 566, 15, 0, 16, -1, -1, -1, 0, 'BTP87141SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 15, 19, 1, 23, 172061), 0, ' ', None, None, 'N', 'BTP87141', ' ', ' ', ' ', datetime.date(2021, 8, 15), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BYC42118', 'SCHOOLS', 'BYC42118', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 19, 1, 45, 53, 83187), datetime.datetime(2021, 8, 19, 1, 45, 53, 83187), datetime.datetime(2021, 8, 19, 1, 45, 53, 83187), datetime.datetime(2021, 8, 19, 1, 56, 55, 114399), 78, 14, 1520, 566, 15, 0, 16, -1, -1, -1, 0, 'BYC42118SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 19, 1, 45, 53, 83187), 0, ' ', None, None, 'N', 'BYC42118', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BYQ48330', 'SCHOOLS', 'BYQ48330', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 11, 0, 0, 52, 300718), datetime.datetime(2021, 8, 11, 0, 0, 52, 300718), datetime.datetime(2021, 8, 11, 0, 0, 52, 300718), datetime.datetime(2021, 8, 11, 0, 8, 4, 172665), 78, 11, 713, 567, 15, 0, 16, -1, -1, -1, 0, 'BYQ48330SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 11, 0, 0, 52, 300718), 0, ' ', None, None, 'N', 'BYQ48330', ' ', ' ', ' ', datetime.date(2021, 8, 11), ' ', 'N', 'R', 'N', -1.0, None),
#  ('BYT96271', 'SCHOOLS', 'BYT96271', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 10, 14, 41, 14, 668265), datetime.datetime(2021, 8, 10, 14, 41, 14, 668265), datetime.datetime(2021, 8, 10, 14, 41, 14, 668265), datetime.datetime(2021, 8, 11, 16, 33, 23, 252462), 78, 4, 1021, 566, 15, 0, 16, -1, -1, -1, 0, 'BYT96271SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 10, 14, 41, 14, 668265), 0, ' ', None, None, 'N', 'BYT96271', ' ', ' ', ' ', datetime.date(2021, 8, 11), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CCX67712', 'SCHOOLS', 'CCX67712', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 16, 20, 19, 12, 335151), datetime.datetime(2021, 8, 16, 20, 19, 12, 335151), datetime.datetime(2021, 8, 16, 20, 19, 12, 335151), datetime.datetime(2021, 8, 16, 20, 21, 54, 909852), 78, 13, 1552, 566, 15, 0, 16, -1, -1, -1, 0, 'CCX67712SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 16, 20, 19, 12, 335151), 0, ' ', None, None, 'N', 'CCX67712', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CQJ29796', 'SCHOOLS', 'CQJ29796', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 9, 7, 4, 38, 999147), datetime.datetime(2021, 8, 9, 7, 4, 38, 999147), datetime.datetime(2021, 8, 9, 7, 4, 38, 999147), datetime.datetime(2021, 8, 9, 7, 13, 5, 60126), 78, 13, 484, 566, 15, 0, 16, -1, -1, -1, 0, 'CQJ29796SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 9, 7, 4, 38, 999147), 0, ' ', None, None, 'N', 'CQJ29796', ' ', ' ', ' ', datetime.date(2021, 8, 9), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CQQ92447', 'SCHOOLS', 'CQQ92447', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 26, 20, 32, 30, 884101), datetime.datetime(2021, 8, 26, 20, 32, 30, 884101), datetime.datetime(2021, 8, 26, 20, 32, 30, 884101), datetime.datetime(2021, 8, 26, 21, 12, 14, 895960), 78, 4, 1889, 566, 15, 0, 16, -1, -1, -1, 0, 'CQQ92447SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 26, 20, 32, 30, 884101), 0, ' ', None, None, 'N', 'CQQ92447', ' ', ' ', ' ', datetime.date(2021, 8, 26), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CSM68913', 'SCHOOLS', 'CSM68913', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 7, 29, 0, 52, 45, 984074), datetime.datetime(2021, 7, 29, 0, 52, 45, 984074), datetime.datetime(2021, 7, 29, 0, 52, 45, 984074), datetime.datetime(2021, 7, 29, 2, 24, 43, 364369), 78, 14, 13, 566, 15, 0, 16, -1, -1, -1, 0, 'CSM68913SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 7, 29, 0, 52, 45, 984074), 0, ' ', None, None, 'N', 'CSM68913', ' ', ' ', ' ', datetime.date(2021, 7, 29), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CTX29714', 'SCHOOLS', 'CTX29714', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 10, 20, 43, 26, 152385), datetime.datetime(2021, 8, 10, 20, 43, 26, 152385), datetime.datetime(2021, 8, 10, 20, 43, 26, 152385), datetime.datetime(2021, 8, 10, 20, 53, 3, 871256), 78, 14, 930, 566, 15, 0, 16, -1, -1, -1, 0, 'CTX29714SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 10, 20, 43, 26, 152385), 0, ' ', None, None, 'N', 'CTX29714', ' ', ' ', ' ', datetime.date(2021, 8, 10), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CYG98324', 'SCHOOLS', 'CYG98324', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 10, 21, 0, 35, 630915), datetime.datetime(2021, 8, 10, 21, 0, 35, 630915), datetime.datetime(2021, 8, 10, 21, 0, 35, 630915), datetime.datetime(2021, 8, 10, 21, 48, 21, 247828), 78, 7, 647, 566, 15, 0, 16, -1, -1, -1, 0, 'CYG98324SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 10, 21, 0, 35, 630915), 0, ' ', None, None, 'N', 'CYG98324', ' ', ' ', ' ', datetime.date(2021, 8, 10), ' ', 'N', 'R', 'N', -1.0, None),
#  ('CYR77677', 'SCHOOLS', 'CYR77677', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 9, 22, 13, 38, 921847), datetime.datetime(2021, 8, 9, 22, 13, 38, 921847), datetime.datetime(2021, 8, 9, 22, 13, 38, 921847), datetime.datetime(2021, 8, 9, 22, 23, 5, 77923), 78, 18, 443, 566, 15, 0, 16, -1, -1, -1, 0, 'CYR77677SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 9, 22, 13, 38, 921847), 0, ' ', None, None, 'N', 'CYR77677', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('DCK17167', 'SCHOOLS', 'DCK17167', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 12, 10, 0, 44, 704155), datetime.datetime(2021, 8, 12, 10, 0, 44, 704155), datetime.datetime(2021, 8, 12, 10, 0, 44, 704155), datetime.datetime(2021, 8, 12, 10, 13, 3, 820330), 78, 14, 748, 566, 15, 0, 16, -1, -1, -1, 0, 'DCK17167SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 12, 10, 0, 44, 704155), 0, ' ', None, None, 'N', 'DCK17167', ' ', ' ', ' ', datetime.date(2021, 8, 12), ' ', 'N', 'R', 'N', -1.0, None),
#  ('DCW23069', 'SCHOOLS', 'DCW23069', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 9, 2, 13, 34, 42, 528457), datetime.datetime(2021, 9, 2, 13, 34, 42, 528457), datetime.datetime(2021, 9, 2, 13, 34, 42, 528457), datetime.datetime(2021, 9, 2, 13, 37, 15, 416669), 78, 15, 1398, 566, 15, 0, 16, -1, -1, -1, 0, 'DCW23069SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021,
PACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 7, 4, 12, 11, 278479), 0, ' ', None, None, 'N', 'GKH64724', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('GKM96240', 'SCHOOLS', 'GKM96240', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 8, 8, 29, 55, 371735), datetime.datetime(2021, 8, 8, 8, 29, 55, 371735), datetime.datetime(2021, 8, 8, 8, 29, 55, 371735), datetime.datetime(2021, 8, 8, 8, 43, 4, 346950), 78, 13, 496, 566, 15, 0, 16, -1, -1, -1, 0, 'GKM96240SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 8, 8, 29, 55, 371735), 0, ' ', None, None, 'N', 'GKM96240', ' ', ' ', ' ', datetime.date(2021, 8, 8), ' ', 'N', 'R', 'N', -1.0, None),
#  ('GMP88112', 'SCHOOLS', 'GMP88112', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 10, 22, 41, 20, 202231), datetime.datetime(2021, 8, 10, 22, 41, 20, 202231), datetime.datetime(2021, 8, 10, 22, 41, 20, 202231), datetime.datetime(2021, 8, 10, 22, 43, 4, 39326), 78, 12, 451, 566, 15, 0, 16, -1, -1, -1, 0, 'GMP88112SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 10, 22, 41, 20, 202231), 0, ' ', None, None, 'N', 'GMP88112', ' ', ' ', ' ', datetime.date(2021, 8, 21), ' ', 'N', 'R', 'N', -1.0, None),
#  ('GNY28792', 'SCHOOLS', 'GNY28792', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 9, 5, 8, 53, 12, 339692), datetime.datetime(2021, 9, 5, 8, 53, 12, 339692), datetime.datetime(2021, 9, 5, 8, 53, 12, 339692), datetime.datetime(2021, 9, 5, 10, 22, 14, 925196), 78, 13, 1473, 566, 15, 0, 16, -1, -1, -1, 0, 'GNY28792SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 9, 5, 8, 53, 12, 339692), 0, ' ', None, None, 'N', 'GNY28792', ' ', ' ', ' ', datetime.date(2021, 9, 5), ' ', 'N', 'R', 'N', -1.0, None),
# ...
#  ('YYB80176', 'SCHOOLS', 'YYB80176', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 19, 3, 6, 21, 327514), datetime.datetime(2021, 8, 19, 3, 6, 21, 327514), datetime.datetime(2021, 8, 19, 3, 6, 21, 327514), datetime.datetime(2021, 8, 19, 3, 11, 55, 237459), 78, 14, 1196, 566, 15, 0, 16, -1, -1, -1, 0, 'YYB80176SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 19, 3, 6, 21, 327514), 0, ' ', None, None, 'N', 'YYB80176', ' ', ' ', ' ', datetime.date(2021, 8, 19), ' ', 'N', 'R', 'N', -1.0, None),
#  ('YZX60339', 'SCHOOLS', 'YZX60339', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 11, 1, 52, 51, 380885), datetime.datetime(2021, 8, 11, 1, 52, 51, 380885), datetime.datetime(2021, 8, 11, 1, 52, 51, 380885), None, 78, 6, 575, -1, -1, -1, -1, -1, -1, -1, -1, 'YZX60339SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, -1, 'N', 999, -1, -1.0, -1, -1.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', -1, datetime.datetime(2021, 8, 11, 1, 52, 51, 380885), 0, ' ', None, None, 'N', 'YZX60339', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None),
#  ('ZBG23977', 'SCHOOLS', 'ZBG23977', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 20, 16, 30, 3, 799009), datetime.datetime(2021, 8, 20, 16, 51, 19, 511372), datetime.datetime(2021, 8, 20, 16, 51, 19, 511380), datetime.datetime(2021, 8, 20, 17, 17, 23, 366255), 78, 6, 1562, 566, 15, 0, 16, -1, -1, -1, 0, 'ZBG23977SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 20, 16, 30, 3, 799009), 0, ' ', None, None, 'N', 'ZBG23977', ' ', ' ', ' ', datetime.date(2021, 8, 20), ' ', 'N', 'R', 'N', -1.0, None),
#  ('ZBM62418', 'SCHOOLS', 'ZBM62418', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8,
' ', 'N', 'R', 'N', -1.0, None),
#  ('ZWB81929', 'SCHOOLS', 'ZWB81929', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 22, 2, 47, 28, 975639), datetime.datetime(2021, 8, 22, 2, 47, 28, 975639), datetime.datetime(2021, 8, 22, 2, 47, 28, 975639), datetime.datetime(2021, 8, 22, 2, 51, 55, 328453), 78, 14, 997, 566, 15, 0, 16, -1, -1, -1, 0, 'ZWB81929SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 22, 2, 47, 28, 975639), 0, ' ', None, None, 'N', 'ZWB81929', ' ', ' ', ' ', datetime.date(2021, 8, 22), ' ', 'N', 'R', 'N', -1.0, None),
#  ('ZWF73170', 'SCHOOLS', 'ZWF73170', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 8, 9, 8, 56, 987745), datetime.datetime(2021, 8, 8, 9, 8, 56, 987745), datetime.datetime(2021, 8, 8, 9, 8, 56, 987745), datetime.datetime(2021, 8, 8, 9, 13, 4, 460169), 78, 6, 766, 566, 15, 0, 16, -1, -1, -1, 0, 'ZWF73170SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 8, 9, 8, 56, 987745), 0, ' ', None, None, 'N', 'ZWF73170', ' ', ' ', ' ', datetime.date(2021, 8, 8), ' ', 'N', 'R', 'N', -1.0, None),
#  ('ZXM62304', 'SCHOOLS', 'ZXM62304', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 13, 23, 10, 20, 412894), datetime.datetime(2021, 8, 13, 23, 10, 20, 412894), datetime.datetime(2021, 8, 13, 23, 10, 20, 412894), datetime.datetime(2021, 8, 14, 0, 48, 23, 383948), 78, 7, 1350, 566, 15, 0, 16, -1, -1, -1, 0, 'ZXM62304SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 13, 23, 10, 20, 412894), 0, ' ', None, None, 'N', 'ZXM62304', ' ', ' ', ' ', datetime.date(2021, 8, 13), ' ', 'N', 'R', 'N', -1.0, None),
#  ('ZZB30894', 'SCHOOLS', 'ZZB30894', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 8, 26, 15, 50, 13, 229243), datetime.datetime(2021, 8, 26, 15, 50, 13, 229243), datetime.datetime(2021, 8, 26, 15, 50, 13, 229243), datetime.datetime(2021, 8, 26, 15, 51, 55, 200004), 78, 13, 934, 566, 15, 0, 16, -1, -1, -1, 0, 'ZZB30894SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 843, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 8, 26, 15, 50, 13, 229243), 0, ' ', None, None, 'N', 'ZZB30894', ' ', ' ', ' ', datetime.date(1, 1, 1), ' ', 'N', 'R', 'N', -1.0, None)]

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
      where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.TABLES contains the table metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA='YOUR-DB2-USERNAME'
#
# or, you can retrieve list of all tables where the schema name is not one of the system created ones:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
#       where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
#
# or, just query for a specifc table that you want to verify exists in the database
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(22650,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.COLUMNS contains the column metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# or
#
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Questions
#
# 1.  Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
# 2.  What is the name of "Community Area Name" column in your table? Does it have spaces?
# 3.  Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "\_"?

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(462,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Which column specifies the school type e.g. 'ES', 'MS', 'HS'? ("Elementary School, Middle School, High School")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Does the column name have mixed case, spaces or other special characters?
# If so, ensure you use double quotes around the "Name of the Column"
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SCHOOLS where school_type = 'ES'
#
# Correct answer: 462
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %%
# %sql select max(SAFETY_SCORE) from SCHOOLS
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(99,)]

# %%
# %sql select count(*) from SCHOOLS where SAFETY_SCORE = 99
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(19,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the MAX() function
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
#
# Correct answer: 99
# -->

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %%
# %sql select NAME_OF_SCHOOL from SCHOOLS where SAFETY_SCORE = 99
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# In the previous problem we found out that the highest Safety Score is 99, so we can use that as an input in the where clause:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where Safety_Score = 99
#
# or, a better way:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where \
#   Safety_Score= (select MAX(Safety_Score) from SCHOOLS)
#
#
# Correct answer: several schools with with Safety Score of 99.
# -->

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %sql select max(AVERAGE_STUDENT_ATTENDANCE) from SCHOOLS
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('98.40%',)]

# %%
# %sql select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from SCHOOLS \
    order by AVERAGE_STUDENT_ATTENDANCE desc nulls last limit 10
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
#     order by Average_Student_Attendance desc nulls last limit 10
#
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %sql select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from SCHOOLS \
    order by AVERAGE_STUDENT_ATTENDANCE asc nulls last limit 5
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %sql SELECT NAME_OF_SCHOOL, REPLACE(AVERAGE_STUDENT_ATTENDANCE, '%', '') \
     from SCHOOLS \
     order by AVERAGE_STUDENT_ATTENDANCE \
     fetch first 5 rows only
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the REPLACE() function to replace '%' with ''
# See documentation for this function at:
# https://www.ibm.com/support/knowledgecenter/en/SSEPGG_10.5.0/com.ibm.db2.luw.sql.ref.doc/doc/r0000843.html
# -->

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %%
# %sql SELECT NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE  \
     from SCHOOLS \
     where DECIMAL ( REPLACE(AVERAGE_STUDENT_ATTENDANCE, '%', '') ) < 70 \
     order by AVERAGE_STUDENT_ATTENDANCE
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# The datatype of the "Average_Student_Attendance" column is varchar.
# So you cannot use it as is in the where clause for a numeric comparison.
# First use the CAST() function to cast it as a DECIMAL or DOUBLE
# e.g. CAST("Column_Name" as DOUBLE)
# or simply: DECIMAL("Column_Name")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget the '%' age sign needs to be removed before casting
# -->

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %%
# %sql SELECT NAME_OF_SCHOOL, COLLEGE_ENROLLMENT, COMMUNITY_AREA_NAME\
     from SCHOOLS \
     order by COMMUNITY_AREA_NAME

# %%
# %sql select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) AS TOTAL_ENROLLMENT \
   from SCHOOLS \
   group by COMMUNITY_AREA_NAME
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
#  ('IRVING PARK', 7764),
#  ('JEFFERSON PARK', 1755),
#  ('KENWOOD', 4287),
#  ('LAKE VIEW', 7055),
#  ('LINCOLN PARK', 5615),
#  ('LINCOLN SQUARE', 4132),
#  ('LOGAN SQUARE', 7351),
#  ('LOOP', 871),
#  ('LOWER WEST SIDE', 7257),
#  ('MCKINLEY PARK', 1552),
#  ('MONTCLARE', 1317),
#  ('MORGAN PARK', 3271),
#  ('MOUNT GREENWOOD', 2091),
#  ('NEAR NORTH SIDE', 3362),
#  ('NEAR SOUTH SIDE', 1378),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('NORTH CENTER', 7541),
#  ('NORTH LAWNDALE', 5146),
#  ('NORTH PARK', 4210),
#  ('NORWOOD PARK', 6469),
#  ('OAKLAND', 140),
#  ('OHARE', 786),
#  ('PORTAGE PARK', 6954),
#  ('PULLMAN', 1620),
#  ('RIVERDALE', 1547),
#  ('ROGERS PARK', 4068),
#  ('ROSELAND', 7020),
#  ('SOUTH CHICAGO', 4043),
#  ('SOUTH DEERING', 1859),
#  ('SOUTH LAWNDALE', 14793),
#  ('SOUTH SHORE', 4543),
#  ('UPTOWN', 4388),
#  ('WASHINGTON HEIGHTS', 4006),
#  ('WASHINGTON PARK', 2648),
#  ('WEST ELSDON', 3700),
#  ('WEST ENGLEWOOD', 5946),
#  ('WEST GARFIELD PARK', 2622),
#  ('WEST LAWN', 4207),
#  ('WEST PULLMAN', 3240),
#  ('WEST RIDGE', 8197),
#  ('WEST TOWN', 9429),
#  ('WOODLAWN', 4206)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Verify the exact name of the Enrollment column in the database
# Use the SUM() function to add up the Enrollments for each Community Area
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget to group by the Community Area
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %sql select COMMUNITY_AREA_NAME, sum(COLLEGE_ENROLLMENT) AS TOTAL_ENROLLMENT \
   from SCHOOLS \
   group by COMMUNITY_AREA_NAME \
   order by TOTAL_ENROLLMENT asc \
   fetch first 5 rows only
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Order the previous query and limit the number of rows you fetch
# -->

# %% [markdown]
# ### Problem 10
#
# ##### List 5 schools with lowest safety score.

# %%
# Way a) of doing it

# %sql select NAME_OF_SCHOOL, SAFETY_SCORE \
   from SCHOOLS \
   order by SAFETY_SCORE asc \
   fetch first 5 rows only
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %%
# Way b) of doing it

# %sql SELECT NAME_OF_SCHOOL, SAFETY_SCORE \
FROM SCHOOLS \
ORDER BY SAFETY_SCORE \
LIMIT 5
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has College Enrollment of 4368

# %%
# %%sql
# select HARDSHIP_INDEX
#    from CHICAGO_SOCIOECONOMIC_DATA CD, SCHOOLS CPS
#    where CD.CA = CPS.COMMUNITY_AREA_NUMBER
#       and COLLEGE_ENROLLMENT = 4368
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(6.0,)]

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %%sql
# select hardship_index
#    from chicago_socioeconomic_data CD, schools CPS
#    where CD.ca = CPS.community_area_number
#       and college_enrollment = 4368
#
# -->

# %% [markdown]
# ### Problem 12
#
# ##### Get the hardship index for the community area which has the school with the  highest enrollment.

# %%
# %sql select max(COLLEGE_ENROLLMENT) from SCHOOLS
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# Done.
# [(4368,)]

# %%
# %%sql
# select HARDSHIP_INDEX
#    from CHICAGO_SOCIOECONOMIC_DATA CD, SCHOOLS CPS
#    where CD.CA = CPS.COMMUNITY_AREA_NUMBER
#       and COLLEGE_ENROLLMENT?
# Out:
#  * ibm_db_sa://trz01921:***@ba99a9e6-d59e-4883-8fc0-d6a8c9f7a08f.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:31321/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0120N  Invalid use of an aggregate function or OLAP function.  SQLSTATE=42903 SQLCODE=-120
# [SQL: select HARDSHIP_INDEX
#    from CHICAGO_SOCIOECONOMIC_DATA CD, SCHOOLS CPS
#    where CD.CA = CPS.COMMUNITY_AREA_NUMBER
#       and max(COLLEGE_ENROLLMENT)]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
#    where ca in \
#    ( select community_area_number from schools order by college_enrollment desc limit 1 )
#
# -->

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Rav Ahuja</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                        |
# | ----------------- | ------- | ----------------- | ----------------------------------------- |
# | 2021-07-09        | 2.4     | Malika            | Updated connection string                 |
# | 2021-05-19        | 2.3     | Lakshmi Holla     | Updated question                          |
# | 2021-04-20        | 2.2     | Malika            | Added the libraries                       |
# | 2020-11-27        | 2.1     | Sannareddy Ramesh | Modified data sets and added new problems |
# | 2020-08-28        | 2.0     | Lavanya           | Moved lab to course repo in GitLab        |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
